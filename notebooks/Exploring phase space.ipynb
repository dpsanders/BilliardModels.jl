# %%
include("../src/Wang_Landau.jl")
# Out:
# explore_phase_space (generic function with 4 methods)

# %%
using PyPlot

# %%
xs, ys, thetas, free_paths = explore_phase_space(0.3, 0.01, 1000000);

# %%
plot(xs, ys, alpha=0.5)
axis("image")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11b780bd0>)
# (-0.4999977560526506,0.4999974815262893,-0.49999777387548505,0.49999276906109147)

# %%
# Out:
# (0.0:1.0:100.0,[639757,218668,60575,24485,13138,7843,4810,3351,2593,2118  …  15,26,27,28,28,25,20,30,14,14])

# %%
h = hist(free_paths[free_paths.<1000], 100)
h1, h2 = h
loglog(h1[1:end-1], h2)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11b1bcf50>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x11c062c90>

# %%
thetas
# Out:
# 99819-element Array{Float64,1}:
#  -1.8368
#  -1.83799
#  -1.83409
#  -1.83057
#  -1.83382
#  -1.83162
#  -1.829
#  -1.832
#  -1.83142
#  -1.83076
#  -1.82999
#  -1.83209
#  -1.83348
#   ⋮
#  -1.85933
#  -1.85702
#  -1.85762
#  -1.85277
#  -1.85107
#  -1.85129
#  -1.85342
#  -1.85339
#  -1.85762
#  -1.85557
#  -1.86031
#  -1.86319

# %%
plot(thetas)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11ba13f50>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x11bd57110>
