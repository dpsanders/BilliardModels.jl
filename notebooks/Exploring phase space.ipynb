# %%
include("../src/Wang_Landau.jl")
# Out:
# explore_phase_space (generic function with 3 methods)

# %%
using PyPlot

# %%
xs, ys = explore_phase_space(0.3, 0.1, 10000)
# Out:
# ([-0.315949,-0.353652,-0.313874,-0.286682,-0.237678,-0.215385,-0.181255,-0.162937,-0.140725,-0.11945  …  0.317297,0.310986,0.332362,0.334374,0.289588,0.309014,0.304548,0.299683,0.324665,0.340745],[0.292031,0.308695,0.336144,0.350892,0.386909,0.384553,0.40665,0.37321,0.332429,0.294322  …  -0.182388,-0.173984,-0.157484,-0.184457,-0.137864,-0.106264,-0.087818,-0.0953678,-0.0725937,-0.0580726])

# %%
plot(xs, ys)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1202c4250>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x12077fe10>
